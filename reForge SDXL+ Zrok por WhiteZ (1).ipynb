# %% [markdown]
# # **SD Forge Neo + Zrok para Lightning.ai**

# %% [markdown]
# **1.1. Copia y pega lo siguiente en la terminal de JupyterLab (Lightning.ai)**<br>
# Cuando aparezca el kernel `Python 3.11 (py311)`, reinicia desde `Kernel → Restart Kernel and Clear Outputs` y vuelve a elegirlo.

# %% [markdown]
# **1. Prepara y limpia el espacio de trabajo antes de instalar** (puedes ejecutarlo en CPU).

# %%
# !conda create -n py311 python=3.11 -y

# !conda activate py311
# !conda install ipykernel -y

# !python -m ipykernel install --user \
       --name py311 \
       --display-name "Python 3.11 (py311)
# Out:
# Error: Conda create is not allowed. A Studio has a default conda environment (max 1 environment). Start a new Studio to create a new environment.
# Error: Conda activate is not allowed. A Studio has a default conda environment (max 1 environment). Start a new Studio to create a new environment.
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
from pathlib import Path
import os
import shutil

BASE_PATH = Path("/teamspace/studios/this_studio")
TMP_ROOT = Path("/tmp")
REPO_NAME = "sd-webui-forge-neo"
REPO_DIR = BASE_PATH / REPO_NAME

env_map = {
    "BASE_PATH": str(BASE_PATH),
    "REPO_DIR": str(REPO_DIR),
    "TMP_ROOT": str(TMP_ROOT),
    "TMP_MODELS": str(TMP_ROOT / "models"),
    "TMP_CONTROLNET": str(TMP_ROOT / "controlnet_models"),
    "HF_HOME": str(TMP_ROOT / "huggingface"),
    "TORCH_HOME": str(TMP_ROOT / "torch"),
    "TRANSFORMERS_CACHE": str(TMP_ROOT / "transformers"),
    "XDG_CACHE_HOME": str(TMP_ROOT / "xdg-cache"),
}
for key, value in env_map.items():
    os.environ[key] = value

def safe_remove(path: Path):
    try:
        if path.is_symlink() or path.is_file():
            path.unlink(missing_ok=True)
        elif path.exists() and path.is_dir():
            shutil.rmtree(path, ignore_errors=True)
    except FileNotFoundError:
        pass

for target in [REPO_DIR, BASE_PATH / "tmp"]:
    safe_remove(target)

for key in ("TMP_MODELS", "TMP_CONTROLNET", "HF_HOME", "TORCH_HOME", "TRANSFORMERS_CACHE", "XDG_CACHE_HOME"):
    folder = Path(os.environ[key])
    safe_remove(folder)
    folder.mkdir(parents=True, exist_ok=True)

symlink_target = BASE_PATH / "tmp"
if not symlink_target.exists():
    symlink_target.symlink_to(TMP_ROOT, target_is_directory=True)

print("Entorno inicializado:")
for key in ("BASE_PATH", "REPO_DIR", "TMP_MODELS", "TMP_CONTROLNET"):
    print(f"  {key} = {os.environ[key]}")
# Out:
# Entorno inicializado:
#   BASE_PATH = /teamspace/studios/this_studio
#   REPO_DIR = /teamspace/studios/this_studio/sd-webui-forge-neo
#   TMP_MODELS = /tmp/models
#   TMP_CONTROLNET = /tmp/controlnet_models

# %% [markdown]
# <h4><b>2. INSTALAR Y ACTUALIZAR PAQUETES</b></h4> (puedes ejecutarlo en CPU).

# %%
import shutil
import subprocess
import sys

def run_pip(*args):
    subprocess.run([sys.executable, "-m", "pip", *args], check=True)

run_pip("install", "--upgrade", "pip")
run_pip("install", "-q", "ipywidgets")

if shutil.which("conda"):
    subprocess.run(["conda", "update", "-n", "base", "-c", "defaults", "conda", "-y"], check=True)
    subprocess.run(["conda", "install", "-c", "conda-forge", "ipykernel", "-y"], check=True)
else:
    print("Conda no está disponible en Lightning.ai; se omite su actualización.")

print("Proceso terminado, puedes seguir con las demás celdas.")

# !sudo apt install aria2 -q
# Out:
# Requirement already satisfied: pip in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (25.3)
# Conda no está disponible en Lightning.ai; se omite su actualización.
# Proceso terminado, puedes seguir con las demás celdas.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libaria2-0 libcares2 libssh2-1t64
# The following NEW packages will be installed:
#   aria2 libaria2-0 libcares2 libssh2-1t64
# 0 upgraded, 4 newly installed, 0 to remove and 7 not upgraded.
# Need to get 1686 kB of archives.
# After this operation, 6117 kB of additional disk space will be used.
# Get:1 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble/main amd64 libcares2 amd64 1.27.0-1.0ubuntu1 [73.7 kB]
# Get:2 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble/main amd64 libssh2-1t64 amd64 1.11.0-4.1build2 [120 kB]
# Get:3 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 libaria2-0 amd64 1.37.0+debian-1build3 [1105 kB]
# Get:4 https://us-east-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 aria2 amd64 1.37.0+debian-1build3 [387 kB]
# Fetched 1686 kB in 1s (2983 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libcares2:amd64.
# (Reading database ... 136777 files and directories currently installed.)
# Preparing to unpack .../libcares2_1.27.0-1.0ubuntu1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libcares2:amd64 (1.27.0-1.0ubuntu1) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1t64:amd64.
# Preparing to unpack .../libssh2-1t64_1.11.0-4.1build2_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1t64:amd64 (1.11.0-4.1build2) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.37.0+debian-1build3_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.37.0+debian-1build3) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.37.0+debian-1build3_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.37.0+debian-1build3) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libcares2:amd64 (1.27.0-1.0ubuntu1) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1t64:amd64 (1.11.0-4.1build2) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.37.0+debian-1build3) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.37.0+debian-1build3) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for libc-bin (2.39-0ubuntu8.6) ...
#
# 78

# %% [markdown]
# <h4><b> 3. Instala Stable Diffusion Forge Neo (branch neo)</b></h4>

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from pathlib import Path
import os
import shutil
import subprocess
import sys

REPO_URL = "https://github.com/Haoming02/sd-webui-forge-classic.git"
REPO_BRANCH = "neo"
REPO_DIR = Path(os.environ["REPO_DIR"])
TMP_MODELS = Path(os.environ["TMP_MODELS"])
TMP_CONTROLNET = Path(os.environ["TMP_CONTROLNET"])

ext_list = [
    "gutris1/sd-hub",
    "zanllp/sd-webui-infinite-image-browsing",
    "Coyote-A/ultimate-upscale-for-automatic1111",
    "DominikDoom/a1111-sd-webui-tagcomplete",
    "Bing-su/adetailer",
    "NoCrypt/sd-fast-pnginfo",
    "BlafKing/sd-civitai-browser-plus",
    "viyiviyi/stable-diffusion-webui-zoomimage",
    "gutris1/sd-simple-dimension-preset",
    "pamparamm/sd-perturbed-attention",
    "anxety-solo/sd-civitai-browser-plus",
    "Bing-su/sd-webui-tunnels",
    "Haoming02/sd-forge-couple",
]

instala = widgets.Button(description="Instalar Forge Neo", button_style="info")
salida = widgets.Output()

def run(cmd):
    subprocess.run(cmd, check=True)

def instalar(_):
    with salida:
        salida.clear_output()
        print("⬇️  Clonando Forge Neo…")
        if REPO_DIR.exists():
            shutil.rmtree(REPO_DIR)
        run(["git", "clone", "--branch", REPO_BRANCH, "--single-branch", REPO_URL, str(REPO_DIR)])

        print("🔗 Configurando carpetas temporales…")
        models_dir = REPO_DIR / "models"
        stable_dir = models_dir / "Stable-diffusion"
        stable_dir.mkdir(parents=True, exist_ok=True)
        tmp_models_link = stable_dir / "tmp_models"
        if tmp_models_link.exists() or tmp_models_link.is_symlink():
            tmp_models_link.unlink()
        tmp_models_link.symlink_to(TMP_MODELS, target_is_directory=True)

        controlnet_dir = models_dir / "ControlNet"
        controlnet_dir.mkdir(parents=True, exist_ok=True)
        tmp_controlnet_link = controlnet_dir / "tmp_controlnet"
        if tmp_controlnet_link.exists() or tmp_controlnet_link.is_symlink():
            tmp_controlnet_link.unlink()
        tmp_controlnet_link.symlink_to(TMP_CONTROLNET, target_is_directory=True)

        print("📦 Descargando modelos ESRGAN…")
        esrgan_dir = models_dir / "ESRGAN"
        esrgan_dir.mkdir(parents=True, exist_ok=True)
        run(["curl", "-Lo", str(esrgan_dir / "4x-UltraSharp.pth"), "https://huggingface.co/Kim2091/AnimeSharp/resolve/main/4x-AnimeSharp.pth"])
        run(["curl", "-Lo", str(esrgan_dir / "4x-AnimeSharp.pth"), "https://huggingface.co/utnah/esrgan/resolve/main/4x-AnimeSharp.pth"])

        print("🧩 Instalando extensiones…")
        ext_dir = REPO_DIR / "extensions"
        ext_dir.mkdir(parents=True, exist_ok=True)
        for ext in ext_list:
            destino = ext_dir / ext.split("/")[1]
            if destino.exists():
                shutil.rmtree(destino)
            run(["git", "clone", "--depth", "1", f"https://github.com/{ext}", str(destino)])

        print("📥 Instalando utilidades (gdown, aria2)…")
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", "gdown", "aria2"], check=True)
        print("✅ Instalación completada.")

instala.on_click(instalar)
display(instala, salida)
# Out:
# Button(button_style='info', description='Instalar Forge Neo', style=ButtonStyle())
# Output()

# %% [markdown]
# <h4><b> 4. Descarga checkpoints al almacenamiento temporal</b></h4>

# %% [markdown]
# <h4><b>MODELOS NOOBAI-ILLUSTRIOUS</b></h4>

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from pathlib import Path
import os

TMP_MODELS = Path(os.environ["TMP_MODELS"])
REPO_DIR = Path(os.environ["REPO_DIR"])
stable_dir = REPO_DIR / "models" / "Stable-diffusion"
stable_dir.mkdir(parents=True, exist_ok=True)
tmp_link = stable_dir / "tmp_models"
if not tmp_link.exists():
    tmp_link.symlink_to(TMP_MODELS, target_is_directory=True)

modelos = {
    "V-pred – waiSHUFFLENOOBvpred v2.0": (
        "https://huggingface.co/WhiteAiZ/waiSHUFFLENOOB_v20/resolve/main/waiSHUFFLENOOB_vPred20.safetensors",
        "waiSHUFFLENOOB_vPred20.safetensors"
    ),
    "V-pred – PersonalMerge vp05": (
        "https://huggingface.co/datasets/John6666/model-mirror-14/resolve/main/illustriousXLPersonalMerge_vp05testLowsteps.safetensors",
        "PersonalMerge_vp05testLowsteps.safetensors"
    ),
    "V-pred – Rouwei_v080Vpred.safetensors": (
        "https://huggingface.co/WhiteAiZ/RouWei/resolve/main/rouwei_v080Vpred.safetensors",
        "rouwei_v080Vpred.safetensors"
    ),
    "EPS – WAI V15": (
        "https://huggingface.co/WhiteAiZ/WAI-NSFW-illustrious-SDXL-V015/resolve/main/waiNSFWIllustrious_v150.safetensors",
        "waiNSFWIllustrious_v150.safetensors"
    ),
    "EPS – ntrMIXIllustriousXL": (
        "https://huggingface.co/misri/ntrMIXIllustriousXL_xiii/resolve/main/ntrMIXIllustriousXL_xiii.safetensors",
        "ntrMIXIllustriousXL_xiii.safetensors"
    ),
    "EPS – ikastrious": (
        "https://huggingface.co/wsj1995/Checkpoint/resolve/main/874216/2002320/ikastrious_v132bStable.safetensors",
        "ikastrious_v132bStable.safetensors"
    ),
    "EPS – waiSHUFFLENOOB v2.0": (
        "https://huggingface.co/WhiteAiZ/waiSHUFFLENOOB_v20/resolve/main/waiSHUFFLENOOB_v20.safetensors",
        "waiSHUFFLENOOB_v20.safetensors"
    ),
}

dropdown = widgets.Dropdown(
    options=list(modelos.keys()),
    description='Modelo:',
    style={'description_width': 'initial'},
    layout={'width': 'max-content'}
)
boton = widgets.Button(description='Descargar', button_style='info')
salida = widgets.Output()

def descargar(_):
    url, nombre = modelos[dropdown.value]
    destino = TMP_MODELS / nombre
    with salida:
        clear_output()
        print(f'⬇️  Descargando {nombre} …')
        get_ipython().system(
            f'aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "{url}" -o "{destino}"'
        )
        print(f'✅ Guardado en {destino}')

boton.on_click(descargar)
display(widgets.HBox([dropdown, boton]), salida)
# Out:
# HBox(children=(Dropdown(description='Modelo:', layout=Layout(width='max-content'), options=('V-pred – waiSHUFF…
# Output()

# %% [markdown]
# <h4><b>Descargar Modelo Opcional</b></h4>

# %%
<h4><b> 5. ControlNet temporales</b></h4>

# %% [markdown]
# **Descargar controlnet union pro max**

# %%
from pathlib import Path
import os
import subprocess

REPO_DIR = Path(os.environ["REPO_DIR"])
TMP_CONTROLNET = Path(os.environ["TMP_CONTROLNET"])
controlnet_dir = REPO_DIR / "models" / "ControlNet"
controlnet_dir.mkdir(parents=True, exist_ok=True)
controlnet_link = controlnet_dir / "tmp_controlnet"
if not controlnet_link.exists():
    controlnet_link.symlink_to(TMP_CONTROLNET, target_is_directory=True)

subprocess.run([
    "aria2c", "--console-log-level=error", "-c", "-x", "16", "-s", "16", "-k", "1M",
    "https://huggingface.co/xinsir/controlnet-union-sdxl-1.0/resolve/main/diffusion_pytorch_model_promax.safetensors",
    "-d", str(TMP_CONTROLNET), "-o", "controlnet_union_promax.safetensors"
], check=True)
print('DESCARGAS TERMINADAS')

# %% [markdown]
# <h4><b> Revisa el espacio disponible</b></h4>

# %%
<h4><b>Ver todas las carpetas y su tamaño</b></h4>

# %% [markdown]
# <h4><b>Ver todas las carpetas y su tamaño</b></h4>

# %%
# !du -h --max-depth=1 "$REPO_DIR" | sort -hr

# %% [markdown]
# <h4><b>Eliminar cache</b></h4> (hazlo después de cada instalación).

# %%
from pathlib import Path
import os
import shutil

cache_dir = Path(os.environ["BASE_PATH"]) / '.cache'
if cache_dir.exists():
    shutil.rmtree(cache_dir, ignore_errors=True)
    print(f'Se eliminó {cache_dir}')
else:
    print('No hay cache que eliminar.')
# Out:
# Se eliminó /teamspace/studios/this_studio/.cache

# %% [markdown]
# <h4><b>Liberar espacio</b></h4> (hazlo después de cada instalación nueva).

# %%
import shutil
import subprocess

if shutil.which('conda'):
    subprocess.run(['conda', 'clean', '--all', '-y'], check=True)
else:
    print('Conda no está disponible; omitiendo limpieza con conda.')

# %% [markdown]
# <h4><b>Borrar y limpiar la carpeta outputs.</b></h4>

# %%
from pathlib import Path
import shutil

outputs_dir = Path(os.environ["REPO_DIR"]) / 'outputs'
if outputs_dir.exists():
    shutil.rmtree(outputs_dir, ignore_errors=True)
    outputs_dir.mkdir(parents=True, exist_ok=True)
    print('Outputs limpiados.')
else:
    print('La carpeta outputs aún no existe.')

# %% [markdown]
# <h5><b>INSTALACION DE ZROK</b></h5>

# %% [markdown]
# No olvide pegar su token NGROK a continuación. Crea un token [aquí](https://dashboard.ngrok.com/get-started/your-authtoken)

# %%
# %cd /tmp
# !wget https://github.com/openziti/zrok/releases/download/v1.1.10/zrok_1.1.10_linux_amd64.tar.gz -q
# !mkdir /tmp/zrok
# !tar -xf ./zrok*linux*.tar.gz -C /tmp/zrok
# !mkdir -p /tmp/zrok/bin && install /tmp/zrok/zrok /tmp/zrok/bin
import os
os.environ['PATH'] = "/tmp/zrok/bin:" + os.environ['PATH']
# !zrok version
# Out:
# /tmp
#                _
#  _____ __ ___ | | __
# |_  / '__/ _ \| |/ /
#  / /| | | (_) |   <
# /___|_|  \___/|_|\_\
#
# v1.1.10 [74eb6fc5]

# %% [markdown]
# #Usar solamente en la terminal para crear cuenta en zrok
# **export PATH=$PATH:/tmp/zrok/bin <p>**
# **zrok invite**

# %% [markdown]
# <h4><b> Activa o desactiva tu token de zrok, usar "enable" + tu token para activar y "disable" sin el token para desactivar</b></h4>

# %%
# !zrok enable rouDjM78m7Hi
# Out:
# [ERROR] you already have an enabled environment, zrok disable first before you zrok enable

# %% [markdown]
# <h5><b>LANZAR SD CON ZROK</b></h5>

# %%
# %cd /teamspace/studios/this_studio/sd-webui-forge-neo
from multiprocessing import Process
import time

def run_command1():
    time.sleep(15)
    # !zrok share public http://localhost:7860 --headless

def run_command2():
    time.sleep(2)
    # !pip install torch==2.7.1
    # !python launch.py --no-hashing  --disable-console-progressbars --xformers --cuda-stream --always-high-vram --enable-insecure-extension-access --theme dark --listen --port 7860 --share

if __name__ == '__main__':
    p1 = Process(target=run_command1)
    p2 = Process(target=run_command2)
    p1.start()
    p2.start()
    p1.join()
    p2.join()
# Out:
# /teamspace/studios/this_studio/sd-webui-forge-neo
# Collecting torch==2.7.1
#   Using cached torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /opt/jupyter/envs/main/lib/python3.10/site-packages (from torch==2.7.1) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/jupyter/envs/main/lib/python3.10/site-packages (from torch==2.7.1) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/jupyter/envs/main/lib/python3.10/site-packages (from torch==2.7.1) (1.14.0)
# Requirement already satisfied: networkx in /opt/jupyter/envs/main/lib/python3.10/site-packages (from torch==2.7.1) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/jupyter/envs/main/lib/python3.10/site-packages (from torch==2.7.1) (3.1.6)
# Requirement already satisfied: fsspec in /opt/jupyter/envs/main/lib/python3.10/site-packages (from torch==2.7.1) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch==2.7.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch==2.7.1)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch==2.7.1)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch==2.7.1)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch==2.7.1)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch==2.7.1)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch==2.7.1)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch==2.7.1)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch==2.7.1)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch==2.7.1)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch==2.7.1)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch==2.7.1)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch==2.7.1)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch==2.7.1)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch==2.7.1)
#   Using cached triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/jupyter/envs/main/lib/python3.10/site-packages (from triton==3.3.1->torch==2.7.1) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/jupyter/envs/main/lib/python3.10/site-packages (from sympy>=1.13.3->torch==2.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/jupyter/envs/main/lib/python3.10/site-packages (from jinja2->torch==2.7.1) (2.1.5)
# Using cached torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
# Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: triton━━━━━━━━━━━━━━━━━━  0/16 [nvidia-cusparselt-cu12]
#     Found existing installation: triton 3.4.0  0/16 [nvidia-cusparselt-cu12]
#     Uninstalling triton-3.4.0:━━━━━━━━━━━━━━  0/16 [nvidia-cusparselt-cu12]
#       Successfully uninstalled triton-3.4.0━  0/16 [nvidia-cusparselt-cu12]
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [triton][   5.757]    INFO main.(*sharePublicCommand).shareLocal: access your zrok share at the following endpoints:
#  https://mlif67v9endn.share.zrok.io
#   Attempting uninstall: nvidia-nvtx-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [triton]
#     Found existing installation: nvidia-nvtx-cu12 12.8.90━━━━━  1/16 [triton]
#     Uninstalling nvidia-nvtx-cu12-12.8.90:━━━━━━━━━━━━━━━━━━━━  1/16 [triton]
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90━━━━━━━  1/16 [triton]
#   Attempting uninstall: nvidia-nvjitlink-cu12━━━━━━━━━━━━━━━━━  1/16 [triton]
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93  1/16 [triton]
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:━━━━━━━━━━━━━━━  1/16 [triton]
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93━━  1/16 [triton]
#   Attempting uninstall: nvidia-nccl-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  3/16 [nvidia-nvjitlink-cu12]
#     Found existing installation: nvidia-nccl-cu12 2.27.3━━━━━━  3/16 [nvidia-nvjitlink-cu12]
#     Uninstalling nvidia-nccl-cu12-2.27.3:━━━━━━━━━━━━━━━━━━━━━  3/16 [nvidia-nvjitlink-cu12]
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3━━━━━━━━  3/16 [nvidia-nvjitlink-cu12]
#   Attempting uninstall: nvidia-curand-cu12━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [nvidia-nccl-cu12]]
#     Found existing installation: nvidia-curand-cu12 10.3.9.90━  4/16 [nvidia-nccl-cu12]
#     Uninstalling nvidia-curand-cu12-10.3.9.90:━━━━━━━━━━━━━━━━  4/16 [nvidia-nccl-cu12]
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90━━━  4/16 [nvidia-nccl-cu12]
#   Attempting uninstall: nvidia-cufile-cu12━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cufile-cu12 1.13.1.3━━  5/16 [nvidia-curand-cu12]
#     Uninstalling nvidia-cufile-cu12-1.13.1.3:━━━━━━━━━━━━━━━━━  5/16 [nvidia-curand-cu12]
#       Successfully uninstalled nvidia-cufile-cu12-1.13.1.3━━━━  5/16 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cuda-runtime-cu12━━━━━━━━━━━━━━  5/16 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90m  5/16 [nvidia-curand-cu12]
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:━━━━━━━━━━━━  5/16 [nvidia-curand-cu12]
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90  5/16 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12━━━━━━━━━━━━━━━━━━━━  7/16 [nvidia-cuda-runtime-cu12]
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93  7/16 [nvidia-cuda-runtime-cu12]
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:━━━━━━━━━━━━━━  7/16 [nvidia-cuda-runtime-cu12]
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93━  7/16 [nvidia-cuda-runtime-cu12]
#   Attempting uninstall: nvidia-cuda-cupti-cu12m━━━━━━━━━━━━━━━━━━━  8/16 [nvidia-cuda-nvrtc-cu12]
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90  8/16 [nvidia-cuda-nvrtc-cu12]
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:━━━━━━━━━━━━━━  8/16 [nvidia-cuda-nvrtc-cu12]
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90━  8/16 [nvidia-cuda-nvrtc-cu12]
#   Attempting uninstall: nvidia-cublas-cu120m━━━━━━━━━━━━━━━━━  9/16 [nvidia-cuda-cupti-cu12]
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1━━  9/16 [nvidia-cuda-cupti-cu12]
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:━━━━━━━━━━━━━━━━━  9/16 [nvidia-cuda-cupti-cu12]
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1━━━━  9/16 [nvidia-cuda-cupti-cu12]
#   Attempting uninstall: nvidia-cusparse-cu12━━━━━━━━━━━━━━ 10/16 [nvidia-cublas-cu12]
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93 10/16 [nvidia-cublas-cu12]
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:━━━━━━━━━━━━━━ 10/16 [nvidia-cublas-cu12]
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93━ 10/16 [nvidia-cublas-cu12]
#   Attempting uninstall: nvidia-cufft-cu1291m╸━━━━━━━━━━━━ 11/16 [nvidia-cusparse-cu12]
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83━━ 11/16 [nvidia-cusparse-cu12]
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:━━━━━━━━━━━━ 11/16 [nvidia-cusparse-cu12]
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83━━━━ 11/16 [nvidia-cusparse-cu12]
#   Attempting uninstall: nvidia-cudnn-cu12m╺━━━━━━━━━ 12/16 [nvidia-cufft-cu12]
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21━━ 12/16 [nvidia-cufft-cu12]
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:━━━━━━━━━ 12/16 [nvidia-cufft-cu12]
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21━━━━ 12/16 [nvidia-cufft-cu12]
#   Attempting uninstall: nvidia-cusolver-cu12╸━━━━━━━ 13/16 [nvidia-cudnn-cu12]
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90 13/16 [nvidia-cudnn-cu12]
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:0m━━━━━━━ 13/16 [nvidia-cudnn-cu12]
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90━ 13/16 [nvidia-cudnn-cu12]
#   Attempting uninstall: torch━━━━━━━━━━━━━━╺━━━━ 14/16 [nvidia-cusolver-cu12]
#     Found existing installation: torch 2.8.0╺━━━━ 14/16 [nvidia-cusolver-cu12]
#     Uninstalling torch-2.8.0:━━━━━━━━━━━━━━━━╸━━ 15/16 [torch]olver-cu12]
#       Successfully uninstalled torch-2.8.0╸━━ 15/16 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [torch]m15/16 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.23.0+cu128 requires torch==2.8.0, but you have torch 2.7.1 which is incompatible.
# xformers 0.0.32.post2 requires torch==2.8.0, but you have torch 2.7.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 torch-2.7.1 triton-3.3.1
# ===========================================================================================
# This program is tested with 3.11.9 Python, but you have 3.10.19.
#             If you encounter any error regarding unsuccessful package/library installation,
#             please downgrade (or upgrade) to the latest version of 3.11 Python,
#             and delete the current Python "venv" folder in WebUI's directory.
#
#             Use --skip-python-version-check to suppress this warning
# ===========================================================================================
# Python 3.10.19 | packaged by conda-forge | (main, Oct 22 2025, 22:29:10) [GCC 14.3.0]
# Version: neo
# Installed version of diffusers (0.35.1) does not satisfy the requirement (==0.31.0).
# Installing diffusers==0.31.0
# Installing SD-Hub requirement: pv lz4
# Installing requirements
# Launching Web UI with arguments: --no-hashing --disable-console-progressbars --xformers --cuda-stream --always-high-vram --enable-insecure-extension-access --theme dark --listen --port 7860 --share
# Total VRAM 22813 MB, total RAM 32093 MB
# pytorch version: 2.8.0+cu128
# xformers version: 0.0.32.post2
# Set vram state to: HIGH_VRAM
# Device: cuda:0 NVIDIA L4 : native
# VAE dtype preferences: [torch.bfloat16, torch.float32] -> torch.bfloat16
# CUDA Using Stream: True
# /opt/jupyter/envs/main/lib/python3.10/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Using xformers Cross Attention
# Using xformers Attention for VAE
# ControlNet preprocessor location: /teamspace/studios/this_studio/sd-webui-forge-neo/models/ControlNetPreprocessor
# Tag Autocomplete: Could not locate model-keyword extension, Lora trigger word completion will be limited to those added through the extra networks menu.
# [-] ADetailer initialized. version: 25.3.0, num models: 10
# [CivitAI-Browser+] - Aria2 RPC started
# [ForgeCouple] - INFO - Loaded Adv. Presets...
# ▶ SD-Hub: v11
# *** Error loading script: GenParamGetter.py
#     Traceback (most recent call last):
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/modules/scripts.py", line 530, in load_scripts
#         script_module = script_loading.load_module(scriptfile.path)
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/modules/script_loading.py", line 13, in load_module
#         module_spec.loader.exec_module(module)
#       File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#       File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/extensions/sd-webui-supermerger/scripts/GenParamGetter.py", line 3, in <module>
#         from scripts.mergers.mergers import smergegen, simggen
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/extensions/sd-webui-supermerger/scripts/mergers/mergers.py", line 27, in <module>
#         from modules.sd_models import  load_model,unload_model_weights
#     ImportError: cannot import name 'load_model' from 'modules.sd_models' (/teamspace/studios/this_studio/sd-webui-forge-neo/modules/sd_models.py)
#
# ---
# *** Error loading script: supermerger.py
#     Traceback (most recent call last):
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/modules/scripts.py", line 530, in load_scripts
#         script_module = script_loading.load_module(scriptfile.path)
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/modules/script_loading.py", line 13, in load_module
#         module_spec.loader.exec_module(module)
#       File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#       File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#       File "/teamspace/studios/this_studio/sd-webui-forge-neo/extensions/sd-webui-supermerger/scripts/supermerger.py", line 19, in <module>
#         from modules.sd_models import checkpoints_loaded, load_model,unload_model_weights
#     ImportError: cannot import name 'checkpoints_loaded' from 'modules.sd_models' (/teamspace/studios/this_studio/sd-webui-forge-neo/modules/sd_models.py)
#
# ---
# 2025-11-01 23:53:37,903 - ControlNet - INFO - ControlNet UI callback registered.
# Model selected: {'checkpoint_info': {'filename': '/teamspace/studios/this_studio/sd-webui-forge-neo/models/Stable-diffusion/tmp_models/waiNSFWIllustrious_v150.safetensors', 'hash': '093aea13'}, 'additional_modules': [], 'unet_storage_dtype': None}
# Using online LoRAs in FP16: False
# Running on local URL:  http://0.0.0.0:7860
# Running on public URL: https://cb9325aeb3befde3a3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# IIB Database file has been successfully backed up to the backup folder.
# Startup time: 111.0s (prepare environment: 85.5s, launcher: 0.5s, forge init: 10.6s, import torch: 0.6s, other imports: 0.8s, load scripts: 3.9s, create ui: 4.6s, gradio launch: 4.0s, add APIs: 0.5s).
# Environment vars changed: {'stream': False, 'inference_memory': 2038.4, 'pin_shared_memory': False}
# [GPU Setting] You will use 91.02% GPU memory (20764.00 MB) to load weights, and use 8.98% GPU memory (2048.00 MB) to do matrix computation.
# Loading Model: {'checkpoint_info': {'filename': '/teamspace/studios/this_studio/sd-webui-forge-neo/models/Stable-diffusion/tmp_models/waiNSFWIllustrious_v150.safetensors', 'hash': '093aea13'}, 'additional_modules': [], 'unet_storage_dtype': None}
# [Unload] Trying to free all memory for cuda:0 with 0 models keep loaded ... Done.
# StateDict Keys: {'unet': 1680, 'vae': 248, 'text_encoder': 197, 'text_encoder_2': 518, 'ignore': 0}
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# K-Model Created: {'storage_dtype': torch.float16, 'computation_dtype': torch.float16}
# Model loaded in 2.7s (unload existing model: 0.4s, forge model load: 2.3s).
# [Unload] Trying to free 4141.61 MB for cuda:0 with 0 models keep loaded ... Done.
# Moving model(s) has taken 0.70 seconds
# [Unload] Trying to free 2038.40 MB for cuda:0 with 1 models keep loaded ... Done.
# [Unload] Trying to free 2038.41 MB for cuda:0 with 0 models keep loaded ... Done.
# Moving model(s) has taken 0.04 seconds
# 100%|███████████████████████████████████████████| 30/30 [00:10<00:00,  2.79it/s]
# [Unload] Trying to free 4794.33 MB for cuda:0 with 0 models keep loaded ... Done.
# Moving model(s) has taken 0.05 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 19
#      17 p1.start()
#      18 p2.start()
# ---> 19 p1.join()
#      20 p2.join()
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:
# ^C
# Interrupted with signal 2 in <frame at 0x7004c81318c0, file '/teamspace/studios/this_studio/sd-webui-forge-neo/modules_forge/main_thread.py', line 43, code loop>
# ^C

# %% [markdown]
# <h5><b>LANZAR SD CON NGROK</b></h5>

# %%
# No te olvides de pegar tu token de NGROK aquí
# %cd $REPO_DIR
import subprocess
import sys

token = 'coloca_tu_token_aqui'  # reemplázalo por tu token real
if token == 'coloca_tu_token_aqui':
    raise ValueError('Reemplaza token por tu token de NGROK antes de ejecutar.')
subprocess.run([
    sys.executable, 'launch.py', '--ngrok', token,
    '--no-hashing', '--disable-console-progressbars', '--disable-xformers',
    '--opt-sdp-attention', '--enable-insecure-extension-access',
    '--theme', 'dark', '--gradio-queue', '--no-download-sd-model'
], check=True)

# %% [markdown]
# <h4><b>🖼️ Descargar carpeta Output</b></h4>

# %%
# download and compress all outputs
import os
import zipfile
from pathlib import Path

outputs_dir = Path(os.environ["REPO_DIR"]) / 'outputs'
destination = Path('outputs')
destination.mkdir(parents=True, exist_ok=True)

def zip_folder(input_folder, output_folder, max_size_mb=199):
    input_folder = Path(input_folder)
    output_folder = Path(output_folder)
    zip_number = 1
    current_zip_name = output_folder / f'part_{zip_number}.zip'
    current_zip = zipfile.ZipFile(current_zip_name, 'w', zipfile.ZIP_DEFLATED)
    current_zip_size = 0

    for root, _, files in os.walk(input_folder):
        for file in files:
            file_path = Path(root) / file
            file_size = file_path.stat().st_size
            if current_zip_size + file_size > max_size_mb * 1024 * 1024:
                current_zip.close()
                zip_number += 1
                current_zip_name = output_folder / f'part_{zip_number}.zip'
                current_zip = zipfile.ZipFile(current_zip_name, 'w', zipfile.ZIP_DEFLATED)
                current_zip_size = 0
            current_zip.write(file_path, file_path.relative_to(input_folder))
            current_zip_size += file_size

    current_zip.close()

if outputs_dir.exists():
    zip_folder(outputs_dir, destination)
    print(f'Carpeta outputs comprimida en {destination.resolve()}')
else:
    print('La carpeta outputs aún no existe.')
